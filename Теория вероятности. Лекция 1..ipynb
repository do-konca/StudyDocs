# %% [markdown]
# # Классическое определение вероятности:
# w<sub>1</sub>, w<sub>2</sub> ... w<sub>n</sub> - элементарные исходы в рамках эксперимента
# 1. Этими вариантами исчерпываются все возможные исходы.
# 2. Все события попарно не совместны (не могут произойти в рамках одного испытания).
# 3. Все исходы равновозможны (потому что определение вероятности классическое).
# <br>Если исходы эксперимента в реальности удовлетворяют этим условиям, то
# >P(w<sub>j</sub>) = 1 / n для всех j = 1...n
#
# O = {w<sub>1</sub>, w<sub>2</sub> ... w<sub>n</sub>} - пространство элементарных событий

# %% [markdown]
# События - некое подмножество множества О, для О их количество 2<sup>n</sup>

# %% [markdown]
# ## Свойства событий

# %% [markdown]
# 1. P(A) принадлежит [0, 1]
# 2. P(A) = 1 <=> A = O
# 3. P(not A) = 1 - P(A)
# 4. P(A объед. B) = P(A) + P(B) - P(A пересеч. B)
# 5. Формула включений/исключений.
# 6. P(A объед. B) <= P(A) + P(B)

# %% [markdown]
# ### Пример:
# # Задача о беспорядках

# %% [markdown]
# Пусть в аудитории есть 70 человек.<br>
# Пусть каждый человек пометит, что место на котором он сейчас сидит это его место.<br>
# Затем всех выгонят из аудитории, и затем посадят на случайные места.<br>
# Найти вероятность того, что никто не сядет на свое место.<br>

# %% [markdown]
# Определим пространство элементарных событий как множество всевозможных рассадок:
# >w<sub>1</sub>, w<sub>2</sub> ... w<sub>70!</sub>

# %% [markdown]
# Мощность этого множества 70!, так как мы считаем всех учеников различными.

# %% [markdown]
# Определим следующие события: <br>
# * A<sub>1</sub> - те рассадки людей, в которых первый человек сидит на своем месте.
# * A<sub>2</sub> - те рассадки людей, в которых второй человек сидит на своем месте.
# * .
# * .
# * A<sub>70</sub> - те рассадки людей, в которых семидесятый человек сидит на своем месте.

# %% [markdown]
# Тогда искомая вероятность будет равна:<fb>
# $$ P = \frac{70! - |A_{1} \cup A_{2} \cup \dots \cup A_{70} |}{70!} $$

# %% [markdown]
# Осталось только посчитать можность этого множества:
# $$ |A_{1} \cup A_{2} \cup \dots \cup A_{70}| = |A_{1}| + |A_{2}| + \dots + |A_{70}| - |A_{1} \cap A_{2}| - |A_{1} \cap A_{3}| + \dots + |A_{1} \cap A_{2} \cap \dots \cap A_{69} | + \dots - |A_{1} \cap A_{2} \cap \dots \cap A_{70} |$$

# %% [markdown]
# Но.

# %% [markdown]
# $$|A_{1}| = С_{70}^1$$ их количество равно 70

# %% [markdown]
# А

# %% [markdown]
# $$|A_{1} \cap A_{2}| = С_{70}^2$$ их количество 70*69

# %% [markdown]
# И так далее...<br>

# %% [markdown]
# В конечном итоге получим, что: $$ P = 1 - \frac{70!}{1!69!}\frac{69!}{70!} + \frac{70!}{2!68!}\frac{68!}{70!} - \frac{70!}{3!67!}\frac{67!}{70!} + \dots + \frac{70!}{69!1!}\frac{1!}{70!} - \frac{70!}{0!70!}\frac{0!}{70!}$$

# %% [markdown]
# Или если сократить члены, то:

# %% [markdown]
# $$ P = 1 - \frac{1}{1!} + \frac{1}{2!} - \frac{1}{3!} + \dots + \frac{1}{69!} - \frac{1}{70!} $$

# %% [markdown]
# А ниже представлено разложение Тейлора для e<sup>x</sup>

# %% [markdown]
# $$ f(x) = 1 + x + \frac{x}{1!} + \frac{x^2}{2!} + \frac{x^3}{3!} + \dots$$

# %% [markdown]
# А теперь подставим x = -1 и вуаля:

# %% [markdown]
# $$ P = e^{-1} + \varepsilon $$

# %% [markdown]
# где 𝜀 оооооооооооооочень мало.

# %% [markdown]
# ###### Катарсис.

# %% [markdown]
# # Геометрическое определение вероятности.

# %% [markdown]
# ### Задача о встрече.

# %% [markdown]
# Пусть есть Коля и Тамара. Они договорились встретиться в столовке с 9 до 10 утра. Если один из них приходит в случайный момент времени, а второго нет, то он ждет 15 минут и уходит. Найти вероятность того, что они встретятся.

# %% [markdown]
# Построим график где по оси x время прихода Коли, а по оси y время прихода Тамары. И предположем, что они приходят не с 9 до 10, а с 0 до 1.

# %% [markdown]
# ![%D0%93%D1%80%D0%B0%D1%84%D0%B8%D0%BA%20%D0%B4%D0%BB%D1%8F%20%D0%B4%D0%B5%D0%BC%D0%BE%D0%BD%D1%81%D1%82%D1%80%D0%B0%D1%86%D0%B8%D0%B8.PNG](attachment:%D0%93%D1%80%D0%B0%D1%84%D0%B8%D0%BA%20%D0%B4%D0%BB%D1%8F%20%D0%B4%D0%B5%D0%BC%D0%BE%D0%BD%D1%81%D1%82%D1%80%D0%B0%D1%86%D0%B8%D0%B8.PNG)

# %% [markdown]
# Нас интересует зеленая область из квадрата, ограниченного красными и синими линиями. Так как эта область отвечает условиям задачи.

# %% [markdown]
# Тогда если найти площадь данного куска, то это и будет искомая вероятность.

# %% [markdown]
# Тогда ответ будет $$ P =  1 - 0.75*0.75 = \frac{7}{16} $$

# %% [markdown]
# В данной задаче элементарными событиями будут, точки на плоскости, а событиями будут области из нашего пространства.

# %% [markdown]
# Свойста геометрической вероятности:

# %% [markdown]
# 1. P(A) принадлежит [0,1]
# 2. A = O <=> P(A) = 1 (Если выкинуть из события, множества меры ноль, то его вероятность не изменится)((пример меры ноль это точка))
# 3. P(not A) = 1-P(A)
# 4. Формула включений и исключений.

# %% [markdown]
# ### Забавный пример

# %% [markdown]
# Если Коля и Тамара ебнулись и решили встретиться только если они оба приходят в один и тот же рациональный момент времени, то шанс их встречи ноль.
